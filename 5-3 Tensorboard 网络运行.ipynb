# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
#载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)



#每个批次的大小
batch_size = 200
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

def variable_summaries(var):
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean',mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var-mean)))
        tf.summary.scalar('stddev',stddev)
        tf.summary.scalar('max',tf.reduce_max(var))
        tf.summary.scalar('min',tf.reduce_min(var))
        tf.summary.histogram('histogram',var)
        
#命名空间
with tf.name_scope('input'):
    #定义placeholder
    x = tf.placeholder(tf.float32, [None,784],name = 'x-input')
    y = tf.placeholder(tf.float32, [None,10],name  = 'y-input')

with tf.name_scope('layer'):  
    #构建神经网络
    with tf.name_scope('weights'):   
        W = tf.Variable(tf.zeros([784,10]),name = 'W')
        variable_summaries(W)
    with tf.name_scope('biase'):
        b = tf.Variable(tf.zeros([1,10]),name = 'b')
        variable_summaries(b)
    with tf.name_scope('wx_plus_b'):
        W_plus_b = tf.matmul(x,W) + b
    with tf.name_scope('softmax'):
        prediction  = tf.nn.softmax(W_plus_b)


#二次代价函数
#loss = tf.reduce_mean(tf.square(y-prediction))
with tf.name_scope('loss'):
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y,logits = prediction))
    tf.summary.scalar('loss',loss)

with tf.name_scope('train'):
    train_step  = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#变量初始化
init = tf.global_variables_initializer()

with tf.name_scope('accuracy'):
    
#结果存放在布尔型列表中
    with tf.name_scope('correct_prediction'):
        correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
    with tf.name_scope('calculate_accuracy'):
#求准确率
        accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
        tf.summary.scalar('accuracy',accuracy)

#合并检测指标
merged = tf.summary.merge_all()
with tf.Session() as sess:
    #变量初始化
    sess.run(init)
    writer = tf.summary.FileWriter('logs/',sess.graph)
    for epoch in range(20):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            
            feed_dict = {x:  batch_xs, y: batch_ys}
            summary,_ = sess.run([merged,train_step],feed_dict)
            #sess.run(train_step,feed_dict)
        writer.add_summary(summary,epoch)
        acc = sess.run(accuracy,feed_dict = {x:mnist.test.images, y:mnist.test.labels})
    #获得预测值
        print("Iter" + str(epoch)+ ", Testing Accuracy="+ str(acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0, Testing Accuracy=0.8108
# Iter1, Testing Accuracy=0.8247
# Iter2, Testing Accuracy=0.8783
# Iter3, Testing Accuracy=0.8935
# Iter4, Testing Accuracy=0.8978
# Iter5, Testing Accuracy=0.9022
# Iter6, Testing Accuracy=0.9043
# Iter7, Testing Accuracy=0.9062
# Iter8, Testing Accuracy=0.9075
# Iter9, Testing Accuracy=0.9087
# Iter10, Testing Accuracy=0.9095
# Iter11, Testing Accuracy=0.9099
# Iter12, Testing Accuracy=0.9111
# Iter13, Testing Accuracy=0.9121
# Iter14, Testing Accuracy=0.9126
# Iter15, Testing Accuracy=0.9135
# Iter16, Testing Accuracy=0.9133
# Iter17, Testing Accuracy=0.9145
# Iter18, Testing Accuracy=0.9158
# Iter19, Testing Accuracy=0.9169
# Iter20, Testing Accuracy=0.9167
# Iter21, Testing Accuracy=0.9167
# Iter22, Testing Accuracy=0.9171
# Iter23, Testing Accuracy=0.919
# Iter24, Testing Accuracy=0.919
# Iter25, Testing Accuracy=0.9184
# Iter26, Testing Accuracy=0.9193
# Iter27, Testing Accuracy=0.9195
# Iter28, Testing Accuracy=0.9188
# Iter29, Testing Accuracy=0.9198
# Iter30, Testing Accuracy=0.9201
# Iter31, Testing Accuracy=0.9207
# Iter32, Testing Accuracy=0.9206
# Iter33, Testing Accuracy=0.9206
# Iter34, Testing Accuracy=0.9209
# Iter35, Testing Accuracy=0.9212
# Iter36, Testing Accuracy=0.9212
# Iter37, Testing Accuracy=0.9215
# Iter38, Testing Accuracy=0.9214
# Iter39, Testing Accuracy=0.9218
# Iter40, Testing Accuracy=0.9221
# Iter41, Testing Accuracy=0.9219
# Iter42, Testing Accuracy=0.9221
# Iter43, Testing Accuracy=0.9224
# Iter44, Testing Accuracy=0.9222
# Iter45, Testing Accuracy=0.9229
# Iter46, Testing Accuracy=0.923
# Iter47, Testing Accuracy=0.9228
# Iter48, Testing Accuracy=0.9229
# Iter49, Testing Accuracy=0.9235
