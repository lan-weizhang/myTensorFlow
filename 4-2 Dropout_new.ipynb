# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
#载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义placeholder
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])
keep_prob = tf.placeholder(tf.float32)

#构建神经网络
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000,1000],stddev=0.1))
b3 = tf.Variable(tf.zeros([1000])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)





#二次代价函数
#loss = tf.reduce_mean(tf.square(y-prediction))

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y,logits = prediction))

train_step  = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#变量初始化
init = tf.global_variables_initializer()

#结果存放在布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))

#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    #变量初始化
    sess.run(init)
    for epoch in range(31):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            feed_dict = {x:  batch_xs, y: batch_ys,keep_prob:0.7}
            sess.run(train_step,feed_dict)
        test_acc = sess.run(accuracy,feed_dict = {x:mnist.test.images, y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,feed_dict = {x:mnist.train.images, y:mnist.train.labels,keep_prob:1.0})
    #获得预测值
        print("Iter" + str(epoch)+ ", Testing Accuracy"+ str(test_acc)+", Training Accuracy"+ str(train_acc))
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-f487381107fd>:4: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-1-f487381107fd>:42: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Iter0, Testing Accuracy0.9127, Training Accuracy0.9088182
# Iter1, Testing Accuracy0.9328, Training Accuracy0.9267091
# Iter2, Testing Accuracy0.9361, Training Accuracy0.9336909
# Iter3, Testing Accuracy0.9422, Training Accuracy0.9408
# Iter4, Testing Accuracy0.9443, Training Accuracy0.94525456
# Iter5, Testing Accuracy0.9472, Training Accuracy0.94707274
# Iter6, Testing Accuracy0.9491, Training Accuracy0.9505636
# Iter7, Testing Accuracy0.9505, Training Accuracy0.95376366
# Iter8, Testing Accuracy0.9522, Training Accuracy0.95567274
# Iter9, Testing Accuracy0.9531, Training Accuracy0.95836365
# Iter10, Testing Accuracy0.9553, Training Accuracy0.95992726
# Iter11, Testing Accuracy0.9598, Training Accuracy0.9626909
# Iter12, Testing Accuracy0.9588, Training Accuracy0.964
# Iter13, Testing Accuracy0.9608, Training Accuracy0.9651273
# Iter14, Testing Accuracy0.9621, Training Accuracy0.9667818
# Iter15, Testing Accuracy0.9619, Training Accuracy0.96645457
# Iter16, Testing Accuracy0.9617, Training Accuracy0.96812725
# Iter17, Testing Accuracy0.9627, Training Accuracy0.96883637
# Iter18, Testing Accuracy0.9642, Training Accuracy0.9701273
# Iter19, Testing Accuracy0.9651, Training Accuracy0.9709273
# Iter20, Testing Accuracy0.965, Training Accuracy0.9707091
# Iter21, Testing Accuracy0.9655, Training Accuracy0.9725636
# Iter22, Testing Accuracy0.9668, Training Accuracy0.9729818
# Iter23, Testing Accuracy0.9677, Training Accuracy0.97403634
# Iter24, Testing Accuracy0.9695, Training Accuracy0.9742
# Iter25, Testing Accuracy0.9676, Training Accuracy0.97481817
# Iter26, Testing Accuracy0.9699, Training Accuracy0.97612727
# Iter27, Testing Accuracy0.9692, Training Accuracy0.97587276
# Iter28, Testing Accuracy0.9702, Training Accuracy0.97685456
# Iter29, Testing Accuracy0.9703, Training Accuracy0.97725457
# Iter30, Testing Accuracy0.9701, Training Accuracy0.97754544
