# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
#载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义placeholder
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])
keep_prob = tf.placeholder(tf.float32)

#构建神经网络
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000,1000],stddev=0.1))
b3 = tf.Variable(tf.zeros([1000])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)





#二次代价函数
#loss = tf.reduce_mean(tf.square(y-prediction))

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y,logits = prediction))

train_step  = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#变量初始化
init = tf.global_variables_initializer()

#结果存放在布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))

#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    #变量初始化
    sess.run(init)
    for epoch in range(31):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            feed_dict = {x:  batch_xs, y: batch_ys,keep_prob:1.0}
            sess.run(train_step,feed_dict)
        test_acc = sess.run(accuracy,feed_dict = {x:mnist.test.images, y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,feed_dict = {x:mnist.train.images, y:mnist.train.labels,keep_prob:1.0})
    #获得预测值
        print("Iter" + str(epoch)+ ", Testing Accuracy"+ str(test_acc)+", Training Accuracy"+ str(train_acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0, Testing Accuracy0.9497, Training Accuracy0.95887274
# Iter1, Testing Accuracy0.9584, Training Accuracy0.97532725
# Iter2, Testing Accuracy0.9635, Training Accuracy0.98227274
# Iter3, Testing Accuracy0.966, Training Accuracy0.9854909
# Iter4, Testing Accuracy0.9671, Training Accuracy0.98752725
# Iter5, Testing Accuracy0.9674, Training Accuracy0.9892909
# Iter6, Testing Accuracy0.9678, Training Accuracy0.9904364
# Iter7, Testing Accuracy0.9698, Training Accuracy0.9910182
# Iter8, Testing Accuracy0.9692, Training Accuracy0.9915818
# Iter9, Testing Accuracy0.969, Training Accuracy0.99216366
# Iter10, Testing Accuracy0.9696, Training Accuracy0.99250907
# Iter11, Testing Accuracy0.9699, Training Accuracy0.9928182
# Iter12, Testing Accuracy0.9705, Training Accuracy0.993
# Iter13, Testing Accuracy0.971, Training Accuracy0.9932
# Iter14, Testing Accuracy0.9711, Training Accuracy0.99343634
# Iter15, Testing Accuracy0.9714, Training Accuracy0.9936182
# Iter16, Testing Accuracy0.9708, Training Accuracy0.9938909
# Iter17, Testing Accuracy0.9709, Training Accuracy0.99396366
# Iter18, Testing Accuracy0.9709, Training Accuracy0.9942
# Iter19, Testing Accuracy0.9705, Training Accuracy0.99432725
# Iter20, Testing Accuracy0.9704, Training Accuracy0.9945818
# Iter21, Testing Accuracy0.9709, Training Accuracy0.99472725
# Iter22, Testing Accuracy0.9714, Training Accuracy0.9947818
# Iter23, Testing Accuracy0.9711, Training Accuracy0.99487275
# Iter24, Testing Accuracy0.9717, Training Accuracy0.995
# Iter25, Testing Accuracy0.9712, Training Accuracy0.9951091
# Iter26, Testing Accuracy0.9711, Training Accuracy0.99523634
# Iter27, Testing Accuracy0.9718, Training Accuracy0.9953091
# Iter28, Testing Accuracy0.9724, Training Accuracy0.99536365
# Iter29, Testing Accuracy0.9717, Training Accuracy0.99545455
# Iter30, Testing Accuracy0.9721, Training Accuracy0.99545455
