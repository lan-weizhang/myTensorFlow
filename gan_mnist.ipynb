# %% [markdown]
# # 利用GAN生成MNIST-demo
#
# 本篇代码将使用GAN来学习MNIST数据集的生成，仅仅作为一个demo演示，后面会更新更加复杂的GAN模型

# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 导入数据

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/Users/Nelson/Desktop/Computer/zhihu/denoise_auto_encoder/MNIST_data/')
# Out:
# Extracting /Users/Nelson/Desktop/Computer/zhihu/denoise_auto_encoder/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /Users/Nelson/Desktop/Computer/zhihu/denoise_auto_encoder/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /Users/Nelson/Desktop/Computer/zhihu/denoise_auto_encoder/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /Users/Nelson/Desktop/Computer/zhihu/denoise_auto_encoder/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
img = mnist.train.images[50]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# # 构建模型
#
# - inputs
# - generator
# - descriminator
# - loss && optimizer

# %% [markdown]
# ## Inputs

# %%
def get_inputs(real_size, noise_size):
    """
    真实图像tensor与噪声图像tensor
    """
    real_img = tf.placeholder(tf.float32, [None, real_size], name='real_img')
    noise_img = tf.placeholder(tf.float32, [None, noise_size], name='noise_img')
    
    return real_img, noise_img

# %% [markdown]
# ## generator

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
    """
    生成器
    
    noise_img: 生成器的输入
    n_units: 隐层单元个数
    out_dim: 生成器输出tensor的size，这里应该为32*32=784
    alpha: leaky ReLU系数
    """
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %% [markdown]
# ## Discriminator

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):
    """
    判别器
    
    n_units: 隐层结点数量
    alpha: Leaky ReLU系数
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %% [markdown]
# ## 定义参数

# %%
# 定义参数
# 真实图像的size
img_size = mnist.train.images[0].shape[0]
# 传入给generator的噪声size
noise_size = 100
# 生成器隐层参数
g_units = 128
# 判别器隐层参数
d_units = 128
# leaky ReLU的参数
alpha = 0.01
# learning_rate
learning_rate = 0.001
# label smoothing
smooth = 0.1

# %%
img_size
# Out:
# 784

# %% [markdown]
# ## 构建网络

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

# generator
g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

# discriminator
d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)

# %% [markdown]
# ## Loss
#
# 这里简单说一下Loss的计算方式，由于我们上面构建了两个神经网络：generator和discriminator，因此需要分别计算loss。
#
# - discriminator
# discriminator的目的在于对于给定的真图片，识别为真（1），对于generator生成的图片，识别为假（0），因此它的loss包含了真实图片的loss和生成器图片的loss两部分。
#
# - generator
# generator的目的在于让discriminator识别不出它的图片是假的，如果用1代表真，0代表假，那么generator生成的图片经过discriminator后要输出为1，因为generator想要骗过discriminator。

# %%
# discriminator的loss
# 识别真实图片
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)) * (1 - smooth))
# 识别生成的图片
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)) * (1 - smooth))

# %% [markdown]
# ## Optimizer
#
# 由于我们在GAN里面一共训练了两个网络，所以需要分别定义优化函数。

# %%
train_vars = tf.trainable_variables()

# generator中的tensor
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator中的tensor
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# # 训练

# %%
# batch_size
batch_size = 64
# 训练迭代轮数
epochs = 300
# 抽取样本数
n_sample = 25

# 存储测试样例
samples = []
# 存储loss
losses = []
# 保存生成器变量
saver = tf.train.Saver(var_list = g_vars)
# 开始训练
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            # 对图像像素进行scale，这是因为tanh输出的结果介于(-1,1),real和fake图片共享discriminator的参数
            batch_images = batch_images*2 - 1
            
            # generator的输入噪声
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        # 每一轮结束计算loss
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        # real img loss
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # fake img loss
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # generator loss
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}(Real: {:.4f} + Fake: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # 记录各类loss值
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        # 抽取样本后期进行观察
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        # 存储checkpoints
        saver.save(sess, './checkpoints/generator.ckpt')

# 将sample的生成数据记录下来
with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.0617(Real: 0.0290 + Fake: 0.0327)... Generator Loss: 3.3821
# Epoch 2/300... Discriminator Loss: 0.5338(Real: 0.2801 + Fake: 0.2536)... Generator Loss: 6.7385
# Epoch 3/300... Discriminator Loss: 0.9485(Real: 0.2005 + Fake: 0.7480)... Generator Loss: 2.5283
# Epoch 4/300... Discriminator Loss: 2.0552(Real: 1.0987 + Fake: 0.9565)... Generator Loss: 0.7485
# Epoch 5/300... Discriminator Loss: 1.0987(Real: 0.6463 + Fake: 0.4524)... Generator Loss: 2.2855
# Epoch 6/300... Discriminator Loss: 1.1321(Real: 0.6169 + Fake: 0.5152)... Generator Loss: 1.3020
# Epoch 7/300... Discriminator Loss: 1.6918(Real: 1.0899 + Fake: 0.6019)... Generator Loss: 1.7268
# Epoch 8/300... Discriminator Loss: 0.3877(Real: 0.2266 + Fake: 0.1610)... Generator Loss: 3.1924
# Epoch 9/300... Discriminator Loss: 0.9729(Real: 0.4253 + Fake: 0.5477)... Generator Loss: 2.7379
# Epoch 10/300... Discriminator Loss: 1.3400(Real: 0.7520 + Fake: 0.5881)... Generator Loss: 1.9835
# Epoch 11/300... Discriminator Loss: 0.6451(Real: 0.5010 + Fake: 0.1441)... Generator Loss: 2.9033
# Epoch 12/300... Discriminator Loss: 1.0252(Real: 0.6209 + Fake: 0.4043)... Generator Loss: 2.1655
# Epoch 13/300... Discriminator Loss: 0.9755(Real: 0.3499 + Fake: 0.6256)... Generator Loss: 1.7021
# Epoch 14/300... Discriminator Loss: 1.2135(Real: 0.7315 + Fake: 0.4820)... Generator Loss: 1.4399
# Epoch 15/300... Discriminator Loss: 0.6841(Real: 0.4748 + Fake: 0.2093)... Generator Loss: 2.3378
# Epoch 16/300... Discriminator Loss: 1.0608(Real: 0.8260 + Fake: 0.2348)... Generator Loss: 2.5207
# Epoch 17/300... Discriminator Loss: 0.8462(Real: 0.3900 + Fake: 0.4562)... Generator Loss: 1.7723
# Epoch 18/300... Discriminator Loss: 0.7326(Real: 0.4390 + Fake: 0.2936)... Generator Loss: 1.9516
# Epoch 19/300... Discriminator Loss: 0.8286(Real: 0.4567 + Fake: 0.3719)... Generator Loss: 1.9428
# Epoch 20/300... Discriminator Loss: 0.9967(Real: 0.4563 + Fake: 0.5405)... Generator Loss: 1.8098
# Epoch 21/300... Discriminator Loss: 0.8334(Real: 0.3983 + Fake: 0.4351)... Generator Loss: 1.6213
# Epoch 22/300... Discriminator Loss: 1.0822(Real: 0.7086 + Fake: 0.3736)... Generator Loss: 1.9071
# Epoch 23/300... Discriminator Loss: 0.5638(Real: 0.2654 + Fake: 0.2984)... Generator Loss: 1.8817
# Epoch 24/300... Discriminator Loss: 0.8561(Real: 0.4562 + Fake: 0.3998)... Generator Loss: 1.7363
# Epoch 25/300... Discriminator Loss: 1.5844(Real: 0.9852 + Fake: 0.5993)... Generator Loss: 1.3522
# Epoch 26/300... Discriminator Loss: 1.0267(Real: 0.3476 + Fake: 0.6790)... Generator Loss: 1.2867
# Epoch 27/300... Discriminator Loss: 0.8150(Real: 0.5527 + Fake: 0.2623)... Generator Loss: 1.9408
# Epoch 28/300... Discriminator Loss: 0.6308(Real: 0.2742 + Fake: 0.3567)... Generator Loss: 1.8603
# Epoch 29/300... Discriminator Loss: 1.3622(Real: 0.5032 + Fake: 0.8591)... Generator Loss: 0.9397
# Epoch 30/300... Discriminator Loss: 1.2917(Real: 0.5869 + Fake: 0.7048)... Generator Loss: 1.0677
# Epoch 31/300... Discriminator Loss: 1.1043(Real: 0.5571 + Fake: 0.5472)... Generator Loss: 1.1444
# Epoch 32/300... Discriminator Loss: 1.0043(Real: 0.3492 + Fake: 0.6551)... Generator Loss: 1.5191
# Epoch 33/300... Discriminator Loss: 0.8694(Real: 0.2558 + Fake: 0.6136)... Generator Loss: 1.1693
# Epoch 34/300... Discriminator Loss: 0.7344(Real: 0.4409 + Fake: 0.2935)... Generator Loss: 1.7789
# Epoch 35/300... Discriminator Loss: 1.1829(Real: 0.5981 + Fake: 0.5848)... Generator Loss: 1.3054
# Epoch 36/300... Discriminator Loss: 1.0328(Real: 0.3773 + Fake: 0.6555)... Generator Loss: 1.0328
# Epoch 37/300... Discriminator Loss: 1.2694(Real: 0.7966 + Fake: 0.4728)... Generator Loss: 1.3115
# Epoch 38/300... Discriminator Loss: 1.1203(Real: 0.5506 + Fake: 0.5697)... Generator Loss: 1.0683
# Epoch 39/300... Discriminator Loss: 1.0923(Real: 0.7304 + Fake: 0.3619)... Generator Loss: 1.7483
# Epoch 40/300... Discriminator Loss: 0.9448(Real: 0.4954 + Fake: 0.4495)... Generator Loss: 1.3761
# Epoch 41/300... Discriminator Loss: 0.9540(Real: 0.5710 + Fake: 0.3831)... Generator Loss: 1.5380
# Epoch 42/300... Discriminator Loss: 0.9877(Real: 0.5093 + Fake: 0.4784)... Generator Loss: 1.3366
# Epoch 43/300... Discriminator Loss: 0.9901(Real: 0.5253 + Fake: 0.4648)... Generator Loss: 1.3282
# Epoch 44/300... Discriminator Loss: 1.0607(Real: 0.3957 + Fake: 0.6650)... Generator Loss: 1.1009
# Epoch 45/300... Discriminator Loss: 1.0022(Real: 0.4606 + Fake: 0.5416)... Generator Loss: 1.1768
# Epoch 46/300... Discriminator Loss: 0.8952(Real: 0.5847 + Fake: 0.3105)... Generator Loss: 1.6687
# Epoch 47/300... Discriminator Loss: 0.9784(Real: 0.3767 + Fake: 0.6018)... Generator Loss: 1.0864
# Epoch 48/300... Discriminator Loss: 0.8641(Real: 0.3175 + Fake: 0.5466)... Generator Loss: 1.1485
# Epoch 49/300... Discriminator Loss: 0.9958(Real: 0.5172 + Fake: 0.4787)... Generator Loss: 1.3003
# Epoch 50/300... Discriminator Loss: 0.9630(Real: 0.5048 + Fake: 0.4582)... Generator Loss: 1.5625
# Epoch 51/300... Discriminator Loss: 1.1148(Real: 0.6979 + Fake: 0.4168)... Generator Loss: 1.3854
# Epoch 52/300... Discriminator Loss: 1.0644(Real: 0.4247 + Fake: 0.6397)... Generator Loss: 1.1734
# Epoch 53/300... Discriminator Loss: 1.1130(Real: 0.5030 + Fake: 0.6100)... Generator Loss: 1.2250
# Epoch 54/300... Discriminator Loss: 1.1798(Real: 0.4999 + Fake: 0.6798)... Generator Loss: 1.2056
# Epoch 55/300... Discriminator Loss: 1.1963(Real: 0.5828 + Fake: 0.6135)... Generator Loss: 1.0762
# Epoch 56/300... Discriminator Loss: 1.0427(Real: 0.6096 + Fake: 0.4331)... Generator Loss: 1.4069
# Epoch 57/300... Discriminator Loss: 0.8912(Real: 0.4582 + Fake: 0.4330)... Generator Loss: 1.5317
# Epoch 58/300... Discriminator Loss: 0.9900(Real: 0.5655 + Fake: 0.4246)... Generator Loss: 1.3529
# Epoch 59/300... Discriminator Loss: 0.8174(Real: 0.4447 + Fake: 0.3727)... Generator Loss: 1.5338
# Epoch 60/300... Discriminator Loss: 1.1174(Real: 0.6576 + Fake: 0.4598)... Generator Loss: 1.4876
# Epoch 61/300... Discriminator Loss: 1.2754(Real: 0.3046 + Fake: 0.9708)... Generator Loss: 0.7311
# Epoch 62/300... Discriminator Loss: 1.0101(Real: 0.4800 + Fake: 0.5301)... Generator Loss: 1.1823
# Epoch 63/300... Discriminator Loss: 1.0972(Real: 0.5055 + Fake: 0.5917)... Generator Loss: 1.0670
# Epoch 64/300... Discriminator Loss: 0.9607(Real: 0.4362 + Fake: 0.5245)... Generator Loss: 1.2130
# Epoch 65/300... Discriminator Loss: 0.9190(Real: 0.5833 + Fake: 0.3357)... Generator Loss: 1.6782
# Epoch 66/300... Discriminator Loss: 0.7839(Real: 0.3401 + Fake: 0.4438)... Generator Loss: 1.2993
# Epoch 67/300... Discriminator Loss: 1.0496(Real: 0.6131 + Fake: 0.4366)... Generator Loss: 1.7078
# Epoch 68/300... Discriminator Loss: 0.8772(Real: 0.4070 + Fake: 0.4702)... Generator Loss: 1.3223
# Epoch 69/300... Discriminator Loss: 0.8078(Real: 0.3198 + Fake: 0.4880)... Generator Loss: 1.3601
# Epoch 70/300... Discriminator Loss: 0.8441(Real: 0.5263 + Fake: 0.3178)... Generator Loss: 1.6736
# Epoch 71/300... Discriminator Loss: 0.9017(Real: 0.6061 + Fake: 0.2956)... Generator Loss: 1.9469
# Epoch 72/300... Discriminator Loss: 0.9670(Real: 0.4586 + Fake: 0.5083)... Generator Loss: 1.3928
# Epoch 73/300... Discriminator Loss: 0.8080(Real: 0.4165 + Fake: 0.3916)... Generator Loss: 1.5157
# Epoch 74/300... Discriminator Loss: 0.8163(Real: 0.4960 + Fake: 0.3203)... Generator Loss: 1.8100
# Epoch 75/300... Discriminator Loss: 0.8337(Real: 0.3077 + Fake: 0.5260)... Generator Loss: 1.2439
# Epoch 76/300... Discriminator Loss: 1.0821(Real: 0.6591 + Fake: 0.4231)... Generator Loss: 1.4917
# Epoch 77/300... Discriminator Loss: 0.8741(Real: 0.4921 + Fake: 0.3820)... Generator Loss: 1.6784
# Epoch 78/300... Discriminator Loss: 1.0393(Real: 0.5416 + Fake: 0.4978)... Generator Loss: 1.3306
# Epoch 79/300... Discriminator Loss: 0.9858(Real: 0.4440 + Fake: 0.5418)... Generator Loss: 1.2092
# Epoch 80/300... Discriminator Loss: 0.9417(Real: 0.3477 + Fake: 0.5940)... Generator Loss: 1.1334
# Epoch 81/300... Discriminator Loss: 0.8073(Real: 0.4399 + Fake: 0.3673)... Generator Loss: 1.7203
# Epoch 82/300... Discriminator Loss: 0.9523(Real: 0.4920 + Fake: 0.4603)... Generator Loss: 1.4923
# Epoch 83/300... Discriminator Loss: 1.0174(Real: 0.5664 + Fake: 0.4510)... Generator Loss: 1.5037
# Epoch 84/300... Discriminator Loss: 0.8013(Real: 0.3659 + Fake: 0.4354)... Generator Loss: 1.2933
# Epoch 85/300... Discriminator Loss: 0.8506(Real: 0.5123 + Fake: 0.3383)... Generator Loss: 1.6679
# Epoch 86/300... Discriminator Loss: 0.8044(Real: 0.4205 + Fake: 0.3840)... Generator Loss: 1.6309
# Epoch 87/300... Discriminator Loss: 1.0138(Real: 0.5272 + Fake: 0.4866)... Generator Loss: 1.2681
# Epoch 88/300... Discriminator Loss: 0.7303(Real: 0.3577 + Fake: 0.3727)... Generator Loss: 1.4353
# Epoch 89/300... Discriminator Loss: 0.9498(Real: 0.5454 + Fake: 0.4044)... Generator Loss: 1.3467
# Epoch 90/300... Discriminator Loss: 0.8841(Real: 0.4603 + Fake: 0.4239)... Generator Loss: 1.3985
# Epoch 91/300... Discriminator Loss: 1.0556(Real: 0.7247 + Fake: 0.3309)... Generator Loss: 1.9762
# Epoch 92/300... Discriminator Loss: 0.8849(Real: 0.3565 + Fake: 0.5284)... Generator Loss: 1.2069
# Epoch 93/300... Discriminator Loss: 0.8133(Real: 0.3828 + Fake: 0.4305)... Generator Loss: 1.4496
# Epoch 94/300... Discriminator Loss: 0.8608(Real: 0.5020 + Fake: 0.3588)... Generator Loss: 1.6487
# Epoch 95/300... Discriminator Loss: 0.9460(Real: 0.5599 + Fake: 0.3861)... Generator Loss: 1.6208
# Epoch 96/300... Discriminator Loss: 0.8854(Real: 0.4622 + Fake: 0.4232)... Generator Loss: 1.5767
# Epoch 97/300... Discriminator Loss: 0.8776(Real: 0.4901 + Fake: 0.3876)... Generator Loss: 1.5625
# Epoch 98/300... Discriminator Loss: 0.9377(Real: 0.5942 + Fake: 0.3435)... Generator Loss: 1.6660
# Epoch 99/300... Discriminator Loss: 0.9318(Real: 0.4436 + Fake: 0.4882)... Generator Loss: 1.3722
# Epoch 100/300... Discriminator Loss: 0.9842(Real: 0.3765 + Fake: 0.6077)... Generator Loss: 1.1150
# Epoch 101/300... Discriminator Loss: 0.8337(Real: 0.4690 + Fake: 0.3647)... Generator Loss: 1.5912
# Epoch 102/300... Discriminator Loss: 0.9175(Real: 0.3703 + Fake: 0.5472)... Generator Loss: 1.3223
# Epoch 103/300... Discriminator Loss: 0.9031(Real: 0.4871 + Fake: 0.4161)... Generator Loss: 1.3990
# Epoch 104/300... Discriminator Loss: 0.8040(Real: 0.3325 + Fake: 0.4715)... Generator Loss: 1.4091
# Epoch 105/300... Discriminator Loss: 1.0666(Real: 0.6375 + Fake: 0.4291)... Generator Loss: 1.6585
# Epoch 106/300... Discriminator Loss: 0.8820(Real: 0.4291 + Fake: 0.4529)... Generator Loss: 1.3416
# Epoch 107/300... Discriminator Loss: 0.7932(Real: 0.4622 + Fake: 0.3310)... Generator Loss: 1.6563
# Epoch 108/300... Discriminator Loss: 1.0502(Real: 0.4844 + Fake: 0.5658)... Generator Loss: 1.2820
# Epoch 109/300... Discriminator Loss: 1.0565(Real: 0.5170 + Fake: 0.5394)... Generator Loss: 1.1737
# Epoch 110/300... Discriminator Loss: 1.0008(Real: 0.4309 + Fake: 0.5699)... Generator Loss: 1.1249
# Epoch 111/300... Discriminator Loss: 0.8760(Real: 0.4277 + Fake: 0.4483)... Generator Loss: 1.3070
# Epoch 112/300... Discriminator Loss: 0.9459(Real: 0.4751 + Fake: 0.4708)... Generator Loss: 1.4305
# Epoch 113/300... Discriminator Loss: 0.7634(Real: 0.3376 + Fake: 0.4258)... Generator Loss: 1.3839
# Epoch 114/300... Discriminator Loss: 0.9520(Real: 0.4287 + Fake: 0.5233)... Generator Loss: 1.2070
# Epoch 115/300... Discriminator Loss: 0.8162(Real: 0.4078 + Fake: 0.4083)... Generator Loss: 1.4083
# Epoch 116/300... Discriminator Loss: 0.7892(Real: 0.4126 + Fake: 0.3766)... Generator Loss: 1.6099
# Epoch 117/300... Discriminator Loss: 1.0206(Real: 0.6584 + Fake: 0.3623)... Generator Loss: 1.7591
# Epoch 118/300... Discriminator Loss: 0.9666(Real: 0.5137 + Fake: 0.4529)... Generator Loss: 1.3909
# Epoch 119/300... Discriminator Loss: 1.2939(Real: 0.6723 + Fake: 0.6216)... Generator Loss: 1.1414
# Epoch 120/300... Discriminator Loss: 1.0865(Real: 0.5932 + Fake: 0.4934)... Generator Loss: 1.3980
# Epoch 121/300... Discriminator Loss: 0.9483(Real: 0.4551 + Fake: 0.4932)... Generator Loss: 1.4505
# Epoch 122/300... Discriminator Loss: 1.1518(Real: 0.6810 + Fake: 0.4707)... Generator Loss: 1.3606
# Epoch 123/300... Discriminator Loss: 0.8901(Real: 0.3966 + Fake: 0.4935)... Generator Loss: 1.1382
# Epoch 124/300... Discriminator Loss: 0.8813(Real: 0.4484 + Fake: 0.4329)... Generator Loss: 1.5862
# Epoch 125/300... Discriminator Loss: 0.7992(Real: 0.3468 + Fake: 0.4524)... Generator Loss: 1.3159
# Epoch 126/300... Discriminator Loss: 1.0285(Real: 0.5755 + Fake: 0.4530)... Generator Loss: 1.5231
# Epoch 127/300... Discriminator Loss: 0.9615(Real: 0.6594 + Fake: 0.3021)... Generator Loss: 1.7593
# Epoch 128/300... Discriminator Loss: 0.8811(Real: 0.4710 + Fake: 0.4100)... Generator Loss: 1.4149
# Epoch 129/300... Discriminator Loss: 0.8738(Real: 0.4644 + Fake: 0.4094)... Generator Loss: 1.4501
# Epoch 130/300... Discriminator Loss: 0.9636(Real: 0.3423 + Fake: 0.6212)... Generator Loss: 1.0723
# Epoch 131/300... Discriminator Loss: 0.8158(Real: 0.3215 + Fake: 0.4943)... Generator Loss: 1.2974
# Epoch 132/300... Discriminator Loss: 1.0399(Real: 0.5171 + Fake: 0.5228)... Generator Loss: 1.2361
# Epoch 133/300... Discriminator Loss: 0.7870(Real: 0.4518 + Fake: 0.3352)... Generator Loss: 1.8094
# Epoch 134/300... Discriminator Loss: 1.0589(Real: 0.6606 + Fake: 0.3983)... Generator Loss: 1.5773
# Epoch 135/300... Discriminator Loss: 0.9368(Real: 0.4038 + Fake: 0.5330)... Generator Loss: 1.2920
# Epoch 136/300... Discriminator Loss: 0.8199(Real: 0.4325 + Fake: 0.3874)... Generator Loss: 1.5512
# Epoch 137/300... Discriminator Loss: 0.9900(Real: 0.4743 + Fake: 0.5157)... Generator Loss: 1.3481
# Epoch 138/300... Discriminator Loss: 0.9403(Real: 0.5868 + Fake: 0.3535)... Generator Loss: 1.6861
# Epoch 139/300... Discriminator Loss: 0.9208(Real: 0.5259 + Fake: 0.3949)... Generator Loss: 1.4421
# Epoch 140/300... Discriminator Loss: 1.1403(Real: 0.6721 + Fake: 0.4683)... Generator Loss: 1.3125
# Epoch 141/300... Discriminator Loss: 0.8135(Real: 0.3123 + Fake: 0.5012)... Generator Loss: 1.2347
# Epoch 142/300... Discriminator Loss: 1.0524(Real: 0.4361 + Fake: 0.6163)... Generator Loss: 1.1809
# Epoch 143/300... Discriminator Loss: 0.7189(Real: 0.3486 + Fake: 0.3702)... Generator Loss: 1.5538
# Epoch 144/300... Discriminator Loss: 0.9333(Real: 0.4675 + Fake: 0.4658)... Generator Loss: 1.4388
# Epoch 145/300... Discriminator Loss: 0.9282(Real: 0.5658 + Fake: 0.3623)... Generator Loss: 1.6089
# Epoch 146/300... Discriminator Loss: 0.9215(Real: 0.3819 + Fake: 0.5395)... Generator Loss: 1.2334
# Epoch 147/300... Discriminator Loss: 1.0095(Real: 0.5743 + Fake: 0.4352)... Generator Loss: 1.5748
# Epoch 148/300... Discriminator Loss: 1.0223(Real: 0.5210 + Fake: 0.5013)... Generator Loss: 1.2737
# Epoch 149/300... Discriminator Loss: 0.9495(Real: 0.4370 + Fake: 0.5126)... Generator Loss: 1.2714
# Epoch 150/300... Discriminator Loss: 0.9529(Real: 0.4839 + Fake: 0.4691)... Generator Loss: 1.4267
# Epoch 151/300... Discriminator Loss: 1.0547(Real: 0.4893 + Fake: 0.5654)... Generator Loss: 1.1411
# Epoch 152/300... Discriminator Loss: 1.1450(Real: 0.5520 + Fake: 0.5930)... Generator Loss: 1.0442
# Epoch 153/300... Discriminator Loss: 1.0500(Real: 0.6573 + Fake: 0.3927)... Generator Loss: 1.5153
# Epoch 154/300... Discriminator Loss: 0.7795(Real: 0.3439 + Fake: 0.4356)... Generator Loss: 1.4099
# Epoch 155/300... Discriminator Loss: 1.1757(Real: 0.6827 + Fake: 0.4931)... Generator Loss: 1.3501
# Epoch 156/300... Discriminator Loss: 1.1421(Real: 0.5613 + Fake: 0.5808)... Generator Loss: 1.1706
# Epoch 157/300... Discriminator Loss: 1.1277(Real: 0.5292 + Fake: 0.5985)... Generator Loss: 1.0435
# Epoch 158/300... Discriminator Loss: 1.0601(Real: 0.5377 + Fake: 0.5225)... Generator Loss: 1.2942
# Epoch 159/300... Discriminator Loss: 1.0633(Real: 0.5013 + Fake: 0.5620)... Generator Loss: 1.3187
# Epoch 160/300... Discriminator Loss: 0.9758(Real: 0.4759 + Fake: 0.4998)... Generator Loss: 1.3669
# Epoch 161/300... Discriminator Loss: 1.1445(Real: 0.6665 + Fake: 0.4780)... Generator Loss: 1.3438
# Epoch 162/300... Discriminator Loss: 1.0013(Real: 0.5176 + Fake: 0.4837)... Generator Loss: 1.2675
# Epoch 163/300... Discriminator Loss: 1.0704(Real: 0.5780 + Fake: 0.4923)... Generator Loss: 1.2521
# Epoch 164/300... Discriminator Loss: 0.9491(Real: 0.4941 + Fake: 0.4549)... Generator Loss: 1.4422
# Epoch 165/300... Discriminator Loss: 0.9034(Real: 0.5423 + Fake: 0.3611)... Generator Loss: 1.6224
# Epoch 166/300... Discriminator Loss: 0.9359(Real: 0.4420 + Fake: 0.4940)... Generator Loss: 1.1351
# Epoch 167/300... Discriminator Loss: 1.0568(Real: 0.5229 + Fake: 0.5339)... Generator Loss: 1.1693
# Epoch 168/300... Discriminator Loss: 1.0177(Real: 0.5426 + Fake: 0.4751)... Generator Loss: 1.3077
# Epoch 169/300... Discriminator Loss: 0.9669(Real: 0.4684 + Fake: 0.4986)... Generator Loss: 1.3155
# Epoch 170/300... Discriminator Loss: 1.0222(Real: 0.4604 + Fake: 0.5618)... Generator Loss: 1.2903
# Epoch 171/300... Discriminator Loss: 1.3106(Real: 0.6530 + Fake: 0.6576)... Generator Loss: 1.2164
# Epoch 172/300... Discriminator Loss: 1.2289(Real: 0.4982 + Fake: 0.7307)... Generator Loss: 1.1728
# Epoch 173/300... Discriminator Loss: 1.1053(Real: 0.5146 + Fake: 0.5907)... Generator Loss: 1.2347
# Epoch 174/300... Discriminator Loss: 0.9682(Real: 0.4249 + Fake: 0.5433)... Generator Loss: 1.2140
# Epoch 175/300... Discriminator Loss: 1.1272(Real: 0.4912 + Fake: 0.6360)... Generator Loss: 1.0328
# Epoch 176/300... Discriminator Loss: 0.9626(Real: 0.5331 + Fake: 0.4295)... Generator Loss: 1.4480
# Epoch 177/300... Discriminator Loss: 0.9253(Real: 0.5445 + Fake: 0.3808)... Generator Loss: 1.4691
# Epoch 178/300... Discriminator Loss: 0.8280(Real: 0.3370 + Fake: 0.4910)... Generator Loss: 1.3712
# Epoch 179/300... Discriminator Loss: 1.1176(Real: 0.5795 + Fake: 0.5380)... Generator Loss: 1.2166
# Epoch 180/300... Discriminator Loss: 1.2430(Real: 0.5350 + Fake: 0.7080)... Generator Loss: 0.9995
# Epoch 181/300... Discriminator Loss: 0.7355(Real: 0.4218 + Fake: 0.3137)... Generator Loss: 1.6003
# Epoch 182/300... Discriminator Loss: 1.1420(Real: 0.4843 + Fake: 0.6577)... Generator Loss: 1.0015
# Epoch 183/300... Discriminator Loss: 1.0222(Real: 0.5240 + Fake: 0.4982)... Generator Loss: 1.3713
# Epoch 184/300... Discriminator Loss: 1.0010(Real: 0.5784 + Fake: 0.4226)... Generator Loss: 1.4370
# Epoch 185/300... Discriminator Loss: 0.8836(Real: 0.4607 + Fake: 0.4229)... Generator Loss: 1.4205
# Epoch 186/300... Discriminator Loss: 0.8814(Real: 0.5357 + Fake: 0.3457)... Generator Loss: 1.5615
# Epoch 187/300... Discriminator Loss: 0.9727(Real: 0.5520 + Fake: 0.4207)... Generator Loss: 1.3293
# Epoch 188/300... Discriminator Loss: 0.9385(Real: 0.4185 + Fake: 0.5199)... Generator Loss: 1.2645
# Epoch 189/300... Discriminator Loss: 0.7513(Real: 0.4248 + Fake: 0.3266)... Generator Loss: 1.8029
# Epoch 190/300... Discriminator Loss: 1.0601(Real: 0.3457 + Fake: 0.7144)... Generator Loss: 1.0459
# Epoch 191/300... Discriminator Loss: 0.9244(Real: 0.5207 + Fake: 0.4037)... Generator Loss: 1.3519
# Epoch 192/300... Discriminator Loss: 0.9700(Real: 0.5374 + Fake: 0.4327)... Generator Loss: 1.4783
# Epoch 193/300... Discriminator Loss: 0.7501(Real: 0.4028 + Fake: 0.3474)... Generator Loss: 1.6748
# Epoch 194/300... Discriminator Loss: 0.9689(Real: 0.6044 + Fake: 0.3646)... Generator Loss: 1.6305
# Epoch 195/300... Discriminator Loss: 0.6696(Real: 0.3428 + Fake: 0.3267)... Generator Loss: 1.6193
# Epoch 196/300... Discriminator Loss: 1.0458(Real: 0.6331 + Fake: 0.4127)... Generator Loss: 1.4720
# Epoch 197/300... Discriminator Loss: 0.9867(Real: 0.4747 + Fake: 0.5121)... Generator Loss: 1.4146
# Epoch 198/300... Discriminator Loss: 0.9632(Real: 0.4117 + Fake: 0.5516)... Generator Loss: 1.3012
# Epoch 199/300... Discriminator Loss: 1.0178(Real: 0.5232 + Fake: 0.4946)... Generator Loss: 1.2733
# Epoch 200/300... Discriminator Loss: 0.8208(Real: 0.4464 + Fake: 0.3744)... Generator Loss: 1.7483
# Epoch 201/300... Discriminator Loss: 0.8367(Real: 0.4156 + Fake: 0.4210)... Generator Loss: 1.4764
# Epoch 202/300... Discriminator Loss: 0.8074(Real: 0.5337 + Fake: 0.2737)... Generator Loss: 1.9865
# Epoch 203/300... Discriminator Loss: 1.0568(Real: 0.5567 + Fake: 0.5001)... Generator Loss: 1.4752
# Epoch 204/300... Discriminator Loss: 0.8610(Real: 0.4663 + Fake: 0.3947)... Generator Loss: 1.4510
# Epoch 205/300... Discriminator Loss: 0.8983(Real: 0.4942 + Fake: 0.4040)... Generator Loss: 1.5059
# Epoch 206/300... Discriminator Loss: 0.8764(Real: 0.3464 + Fake: 0.5300)... Generator Loss: 1.2749
# Epoch 207/300... Discriminator Loss: 0.9772(Real: 0.3446 + Fake: 0.6326)... Generator Loss: 1.1054
# Epoch 208/300... Discriminator Loss: 1.0468(Real: 0.4629 + Fake: 0.5838)... Generator Loss: 1.3279
# Epoch 209/300... Discriminator Loss: 0.9382(Real: 0.5438 + Fake: 0.3944)... Generator Loss: 1.4562
# Epoch 210/300... Discriminator Loss: 1.0482(Real: 0.5337 + Fake: 0.5145)... Generator Loss: 1.3035
# Epoch 211/300... Discriminator Loss: 0.9134(Real: 0.5787 + Fake: 0.3347)... Generator Loss: 1.4722
# Epoch 212/300... Discriminator Loss: 0.8807(Real: 0.4700 + Fake: 0.4108)... Generator Loss: 1.4174
# Epoch 213/300... Discriminator Loss: 0.9359(Real: 0.4152 + Fake: 0.5207)... Generator Loss: 1.1740
# Epoch 214/300... Discriminator Loss: 0.8543(Real: 0.3754 + Fake: 0.4789)... Generator Loss: 1.4298
# Epoch 215/300... Discriminator Loss: 0.9655(Real: 0.5720 + Fake: 0.3935)... Generator Loss: 1.4777
# Epoch 216/300... Discriminator Loss: 1.0070(Real: 0.4526 + Fake: 0.5544)... Generator Loss: 1.3100
# Epoch 217/300... Discriminator Loss: 0.8910(Real: 0.4882 + Fake: 0.4028)... Generator Loss: 1.5538
# Epoch 218/300... Discriminator Loss: 1.1016(Real: 0.4179 + Fake: 0.6836)... Generator Loss: 1.0153
# Epoch 219/300... Discriminator Loss: 0.8407(Real: 0.5412 + Fake: 0.2995)... Generator Loss: 1.7401
# Epoch 220/300... Discriminator Loss: 0.8032(Real: 0.3234 + Fake: 0.4798)... Generator Loss: 1.2849
# Epoch 221/300... Discriminator Loss: 0.8729(Real: 0.5347 + Fake: 0.3382)... Generator Loss: 1.6934
# Epoch 222/300... Discriminator Loss: 0.9821(Real: 0.5769 + Fake: 0.4052)... Generator Loss: 1.5909
# Epoch 223/300... Discriminator Loss: 0.7614(Real: 0.3627 + Fake: 0.3988)... Generator Loss: 1.4005
# Epoch 224/300... Discriminator Loss: 0.8095(Real: 0.3232 + Fake: 0.4863)... Generator Loss: 1.2819
# Epoch 225/300... Discriminator Loss: 0.9893(Real: 0.4600 + Fake: 0.5294)... Generator Loss: 1.1695
# Epoch 226/300... Discriminator Loss: 0.9975(Real: 0.5756 + Fake: 0.4219)... Generator Loss: 1.4637
# Epoch 227/300... Discriminator Loss: 1.0350(Real: 0.4578 + Fake: 0.5772)... Generator Loss: 1.1643
# Epoch 228/300... Discriminator Loss: 0.9594(Real: 0.5274 + Fake: 0.4320)... Generator Loss: 1.4693
# Epoch 229/300... Discriminator Loss: 0.9373(Real: 0.5214 + Fake: 0.4159)... Generator Loss: 1.5248
# Epoch 230/300... Discriminator Loss: 0.8472(Real: 0.4123 + Fake: 0.4348)... Generator Loss: 1.5356
# Epoch 231/300... Discriminator Loss: 0.8686(Real: 0.4603 + Fake: 0.4082)... Generator Loss: 1.3490
# Epoch 232/300... Discriminator Loss: 1.0265(Real: 0.4915 + Fake: 0.5350)... Generator Loss: 1.3660
# Epoch 233/300... Discriminator Loss: 0.7905(Real: 0.3355 + Fake: 0.4550)... Generator Loss: 1.4920
# Epoch 234/300... Discriminator Loss: 0.9973(Real: 0.4858 + Fake: 0.5115)... Generator Loss: 1.2587
# Epoch 235/300... Discriminator Loss: 1.0474(Real: 0.4876 + Fake: 0.5598)... Generator Loss: 1.2702
# Epoch 236/300... Discriminator Loss: 0.8412(Real: 0.2932 + Fake: 0.5480)... Generator Loss: 1.2656
# Epoch 237/300... Discriminator Loss: 1.0493(Real: 0.7032 + Fake: 0.3461)... Generator Loss: 1.8954
# Epoch 238/300... Discriminator Loss: 0.8185(Real: 0.3792 + Fake: 0.4393)... Generator Loss: 1.6626
# Epoch 239/300... Discriminator Loss: 1.0415(Real: 0.5431 + Fake: 0.4984)... Generator Loss: 1.4627
# Epoch 240/300... Discriminator Loss: 1.0774(Real: 0.5229 + Fake: 0.5544)... Generator Loss: 1.3454
# Epoch 241/300... Discriminator Loss: 0.8329(Real: 0.3955 + Fake: 0.4373)... Generator Loss: 1.6542
# Epoch 242/300... Discriminator Loss: 0.8853(Real: 0.4373 + Fake: 0.4480)... Generator Loss: 1.4138
# Epoch 243/300... Discriminator Loss: 0.9569(Real: 0.5164 + Fake: 0.4405)... Generator Loss: 1.6127
# Epoch 244/300... Discriminator Loss: 1.0894(Real: 0.4482 + Fake: 0.6412)... Generator Loss: 1.2106
# Epoch 245/300... Discriminator Loss: 0.9984(Real: 0.5351 + Fake: 0.4633)... Generator Loss: 1.3311
# Epoch 246/300... Discriminator Loss: 0.9251(Real: 0.5601 + Fake: 0.3650)... Generator Loss: 1.5962
# Epoch 247/300... Discriminator Loss: 1.1394(Real: 0.6186 + Fake: 0.5208)... Generator Loss: 1.3391
# Epoch 248/300... Discriminator Loss: 0.9971(Real: 0.5539 + Fake: 0.4431)... Generator Loss: 1.4789
# Epoch 249/300... Discriminator Loss: 0.7499(Real: 0.3336 + Fake: 0.4163)... Generator Loss: 1.4223
# Epoch 250/300... Discriminator Loss: 1.0023(Real: 0.4127 + Fake: 0.5896)... Generator Loss: 1.1965
# Epoch 251/300... Discriminator Loss: 1.0160(Real: 0.5956 + Fake: 0.4205)... Generator Loss: 1.4440
# Epoch 252/300... Discriminator Loss: 0.8260(Real: 0.3923 + Fake: 0.4337)... Generator Loss: 1.6022
# Epoch 253/300... Discriminator Loss: 0.9616(Real: 0.5955 + Fake: 0.3660)... Generator Loss: 1.7815
# Epoch 254/300... Discriminator Loss: 0.9371(Real: 0.4354 + Fake: 0.5017)... Generator Loss: 1.3889
# Epoch 255/300... Discriminator Loss: 0.9953(Real: 0.4124 + Fake: 0.5829)... Generator Loss: 1.3377
# Epoch 256/300... Discriminator Loss: 0.9748(Real: 0.5850 + Fake: 0.3898)... Generator Loss: 1.6799
# Epoch 257/300... Discriminator Loss: 1.0371(Real: 0.5326 + Fake: 0.5045)... Generator Loss: 1.3548
# Epoch 258/300... Discriminator Loss: 0.8225(Real: 0.4653 + Fake: 0.3572)... Generator Loss: 1.4773
# Epoch 259/300... Discriminator Loss: 1.2285(Real: 0.6123 + Fake: 0.6162)... Generator Loss: 1.2264
# Epoch 260/300... Discriminator Loss: 0.8770(Real: 0.4695 + Fake: 0.4075)... Generator Loss: 1.6845
# Epoch 261/300... Discriminator Loss: 0.9289(Real: 0.5018 + Fake: 0.4272)... Generator Loss: 1.5046
# Epoch 262/300... Discriminator Loss: 0.7053(Real: 0.3256 + Fake: 0.3797)... Generator Loss: 1.5323
# Epoch 263/300... Discriminator Loss: 0.7753(Real: 0.4743 + Fake: 0.3010)... Generator Loss: 1.8442
# Epoch 264/300... Discriminator Loss: 0.9530(Real: 0.4072 + Fake: 0.5458)... Generator Loss: 1.2715
# Epoch 265/300... Discriminator Loss: 0.8561(Real: 0.4788 + Fake: 0.3772)... Generator Loss: 1.5656
# Epoch 266/300... Discriminator Loss: 0.8642(Real: 0.2394 + Fake: 0.6248)... Generator Loss: 1.1710
# Epoch 267/300... Discriminator Loss: 0.7821(Real: 0.4392 + Fake: 0.3428)... Generator Loss: 1.7918
# Epoch 268/300... Discriminator Loss: 0.8311(Real: 0.4700 + Fake: 0.3611)... Generator Loss: 1.6991
# Epoch 269/300... Discriminator Loss: 0.8762(Real: 0.5158 + Fake: 0.3604)... Generator Loss: 1.7969
# Epoch 270/300... Discriminator Loss: 0.6949(Real: 0.3441 + Fake: 0.3509)... Generator Loss: 1.6527
# Epoch 271/300... Discriminator Loss: 0.8365(Real: 0.4358 + Fake: 0.4007)... Generator Loss: 1.5078
# Epoch 272/300... Discriminator Loss: 1.0350(Real: 0.4240 + Fake: 0.6110)... Generator Loss: 1.2888
# Epoch 273/300... Discriminator Loss: 1.0178(Real: 0.4078 + Fake: 0.6100)... Generator Loss: 1.2650
# Epoch 274/300... Discriminator Loss: 1.1469(Real: 0.5854 + Fake: 0.5615)... Generator Loss: 1.3535
# Epoch 275/300... Discriminator Loss: 0.8657(Real: 0.2512 + Fake: 0.6145)... Generator Loss: 1.2292
# Epoch 276/300... Discriminator Loss: 0.7933(Real: 0.4024 + Fake: 0.3910)... Generator Loss: 1.7288
# Epoch 277/300... Discriminator Loss: 0.7581(Real: 0.3378 + Fake: 0.4202)... Generator Loss: 1.5001
# Epoch 278/300... Discriminator Loss: 0.8508(Real: 0.3986 + Fake: 0.4522)... Generator Loss: 1.4799
# Epoch 279/300... Discriminator Loss: 0.8215(Real: 0.4153 + Fake: 0.4062)... Generator Loss: 1.6327
# Epoch 280/300... Discriminator Loss: 0.9487(Real: 0.5367 + Fake: 0.4120)... Generator Loss: 1.6472
# Epoch 281/300... Discriminator Loss: 0.8683(Real: 0.4417 + Fake: 0.4265)... Generator Loss: 1.5091
# Epoch 282/300... Discriminator Loss: 0.8330(Real: 0.2969 + Fake: 0.5361)... Generator Loss: 1.2298
# Epoch 283/300... Discriminator Loss: 0.7311(Real: 0.3916 + Fake: 0.3394)... Generator Loss: 2.0465
# Epoch 284/300... Discriminator Loss: 0.9235(Real: 0.4170 + Fake: 0.5064)... Generator Loss: 1.4678
# Epoch 285/300... Discriminator Loss: 1.0919(Real: 0.6654 + Fake: 0.4265)... Generator Loss: 1.5841
# Epoch 286/300... Discriminator Loss: 0.7803(Real: 0.4774 + Fake: 0.3029)... Generator Loss: 2.0584
# Epoch 287/300... Discriminator Loss: 0.8431(Real: 0.5619 + Fake: 0.2812)... Generator Loss: 1.8041
# Epoch 288/300... Discriminator Loss: 0.7696(Real: 0.3627 + Fake: 0.4069)... Generator Loss: 1.6601
# Epoch 289/300... Discriminator Loss: 0.9731(Real: 0.4558 + Fake: 0.5173)... Generator Loss: 1.3412
# Epoch 290/300... Discriminator Loss: 0.8531(Real: 0.4485 + Fake: 0.4046)... Generator Loss: 1.5112
# Epoch 291/300... Discriminator Loss: 0.8910(Real: 0.4679 + Fake: 0.4231)... Generator Loss: 1.3414
# Epoch 292/300... Discriminator Loss: 0.6730(Real: 0.3708 + Fake: 0.3021)... Generator Loss: 2.0489
# Epoch 293/300... Discriminator Loss: 0.7612(Real: 0.2888 + Fake: 0.4724)... Generator Loss: 1.4151
# Epoch 294/300... Discriminator Loss: 0.8414(Real: 0.4827 + Fake: 0.3587)... Generator Loss: 1.5479
# Epoch 295/300... Discriminator Loss: 0.8736(Real: 0.4856 + Fake: 0.3880)... Generator Loss: 1.8168
# Epoch 296/300... Discriminator Loss: 0.8942(Real: 0.2894 + Fake: 0.6048)... Generator Loss: 1.0486
# Epoch 297/300... Discriminator Loss: 0.8088(Real: 0.3707 + Fake: 0.4381)... Generator Loss: 1.4175
# Epoch 298/300... Discriminator Loss: 0.8080(Real: 0.4153 + Fake: 0.3927)... Generator Loss: 1.5230
# Epoch 299/300... Discriminator Loss: 1.0058(Real: 0.5464 + Fake: 0.4594)... Generator Loss: 1.5118
# Epoch 300/300... Discriminator Loss: 0.8236(Real: 0.4350 + Fake: 0.3885)... Generator Loss: 1.6212

# %% [markdown]
# # 绘制loss曲线

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator Total Loss')
plt.plot(losses.T[1], label='Discriminator Real Loss')
plt.plot(losses.T[2], label='Discriminator Fake Loss')
plt.plot(losses.T[3], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# # 显示图像

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
def view_samples(epoch, samples):
    """
    epoch代表第几次迭代的图像
    samples为我们的采样结果
    """
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
_ = view_samples(-1, samples) # 显示最后一轮的outputs

# %% [markdown]
# # 显示整个生成过程图片

# %%
# 指定要查看的轮次
epoch_idx = [0, 5, 10, 20, 40, 60, 80, 100, 150, 250] # 一共300轮，不要越界
#epoch_idx = [0, 5, 10 ,20, 40, 60, 80] # 一共300轮，不要越界
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# # 生成新的图片

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(0, [gen_samples])
